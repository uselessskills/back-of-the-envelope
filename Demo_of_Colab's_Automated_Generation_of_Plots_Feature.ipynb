# %% [markdown]
# <a href="https://colab.research.google.com/github/cwb4-dev/back-of-the-envelope/blob/main/Demo_of_Colab's_Automated_Generation_of_Plots_Feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # bit.ly/478I4tk

# %% [markdown]
# ## **Demo of Colab's Automated Generation of Plots Feature**

# %% [markdown]
# **Step 1:**
#
# Get your data into a python dataframe. We have code snippets to help you import from [Google Sheets](https://colab.research.google.com/notebooks/snippets/sheets.ipynb) or [BigQuery](https://colab.research.google.com/notebooks/bigquery.ipynb)
#
# In this example we'll demonstrate the feature using the standard datasets from the Vega library. **Run the following code cell to load the dataset.**

# %%
import pandas as pd
from vega_datasets import data
df = data.movies()
df

# %%
import numpy as np
from google.colab import autoviz
df_4577765872355980793 = autoviz.get_registered_df('df_4577765872355980793')

def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  _, ax = plt.subplots(figsize=figsize)
  bars = df[colname].value_counts()
  plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df_4577765872355980793, *['MPAA_Rating'], **{})
chart

# %% [markdown]
# **Step 2:**
#
# Once you get your data into a dataframe just finish your code cell with the dataframe to bring up the automated plotting feature (the chart icon on the right). Try it yourself by clicking the chart icon (shown below) in the previous cell's output.
#
#  ![Screenshot 2023-07-10 at 12.36.44 PM.png](data:image/png;base64,...)

# %% [markdown]
# **Step 3:**
#
# The tool will generate a selection of different charts. To get the code to generate one of these sample graphs, click on a graph and then click the "Add Cell" button in the popup dialog to add the desired code into a new cell.
#
# Some things to know:
# - The generated code uses a different variable for the dataframe to avoid collisions with the rest of your notebook.
# - All of your data stays on the kernel (aka runtime or back end) for the VM you are using.
# - To use the plot permanently, you should replace the df with a variable you define above.
#
# Here's a screenshot of the code presented after you select one of the plot previews:
#
# ![Screenshot 2023-07-10 at 3.30.59 PM.png](data:image/png;base64,...)

# %%
import numpy as np
from google.colab import autoviz
#df_3791683756164861932 = autoviz.get_registered_df('df_3791683756164861932')
# Commented the above line out for the Demo we suggest you adjust your code to specify the dataframe you want to call as we've done here.

def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  _, ax = plt.subplots(figsize=figsize)
  bars = df[colname].value_counts()
  plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['MPAA_Rating'], **{})
chart

# %% [markdown]
# **Step 4:**
#
# Adjust the code of your plot to suit your purposes. Sometimes the plots will be perfect as is, but sometimes you might want to add a title, change the formatting, tweak the axes, etc. If you have access to Colab's generative AI tools they can help you directly.

# %%
import numpy as np
from google.colab import autoviz
#df_3791683756164861932 = autoviz.get_registered_df('df_3791683756164861932')
# Commented the above line out for the Demo we suggest you adjust your code to specify the dataframe you want to call as we've done here.

def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  _, ax = plt.subplots(figsize=figsize)
  bars = df[colname].value_counts()
  plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['MPAA_Rating'], **{},figsize=(2,3),mpl_palette_name='turbo')
chart
